# %%
import pandas as pd

# %%
df = pd.read_csv('rc.csv', encoding='windows-1251')

# %%
df.head(30)
# Out:
#    ATC_code                                          applicant  \
# 0   N01BB01                                Гриндекс АО, Латвия
# 1   A03AX13              Киевский витаминный завод АО, Украина
# 2   N05BA23                  EGIS Pharmaceuticals PLC, Венгрия
# 3   P03AX01          Фармацевтическая фабрика ООО ДКП, Украина
# 4   B05AA01  OCTAPHARMA Pharmazeutika Produktionsges.m.b.H....
# 5       NaN            Фармтехнология ООО, Республика Беларусь
# 6   J01FA02  Иностранное производственно-торговое унитарное...
# 7   N05CM18                       EVER Valinject GmbH, Австрия
# 8   L03AB05                   БИОКАД ЗАО, Российская Федерация
# 9   P03AX01            Фармтехнология ООО, Республика Беларусь
# 10  L04AX07                 Нативита СООО, Республика Беларусь
# 11  L02BG06                     Pfizer Export B.V., Нидерланды
# 12  M01AH05               Organon Central East GmbH, Швейцария
# 13  N06AB05                              Medochemie Ltd., Кипр
# ...
